# %%
# AI Application
# !pip3 install wolframalpha==3.0.0

# %%
import wolframalpha

APP_ID = ""
client = wolframalpha.Client(APP_ID)

print('AI Chatbox')


while True:
    user = input('Ask me question: ')

    if user.lower() in ['quit','exit']:
      print('Goodbye!')
      break

    res = client.query(user)

    try:
      answer = next(res.results).text
      print(f'Answer: {answer}')

    except:
      print('Sorry, I could not understand your question.')
# Out:
# AI Chatbox
# Ask me question: Temperature in sabah
# Answer: 84 °F (heat index: 94 °F)
# (1 hour 32 minutes ago)
# Ask me question: Temperature in Kuala lumpur
# Answer: 91 °F (heat index: 101 °F)
# (1 hour 32 minutes ago)
# Ask me question: Population in sabah
# Answer: 3.419 million people (13% of total for Malaysia) (2020 estimate)
# Ask me question: Population in Kuala Lumpur
# Answer: 1.982 million people (country rank: 1st) (2020 estimate)
# Ask me question: the biggest population in malaysia
# Sorry, I could not understand your question.
# Ask me question: Highest number population by state in malaysia
# Answer: 1 | Kuala Lumpur, Malaysia | 7.59 million people |
# 2 | Selangor, Malaysia | 5.288 million people |
# 3 | Sabah, Malaysia | 3.419 million people |
# 4 | Perak, Malaysia | 2.478 million people |
# 5 | Johor, Malaysia | 2.466 million people |
# Ask me question: Biggest state in Malaysia
# Answer: Sarawak, Malaysia
# (47783 mi^2 (square miles))
# Ask me question: second is?
# Sorry, I could not understand your question.
# Ask me question: second biggest state in malaysia
# Answer: Sabah, Malaysia
# (28703.4 mi^2 (square miles))
# Ask me question: exit
# Goodbye!
