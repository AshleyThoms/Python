# %%
# TYPE CASTING
# IT'S A PROCESS OF CONVERTING ONE DATA TYPE TO ANOTHER DATA TYPE

# automatic type conversion
# lower data type will be converted to higher data type automatically

a = 10
b = 45.03
res = a + b  #10.00 + 45.03
print (res)
# Out:
# 55.03

# %%
# manual type conversion EXPLICIT
# performed by developers

a = 10
b = 45.03
res = a + int(b)  #10 + 45
print (res)


# we have a floatVar which needs to be converted into intVar
#  int(floatvar)      int(23.33) --> 23

# we have an intVar which needs to be converted into floatVar
#  float(intVar)     float(10)  --> 10.0

# we have a intVar which needs to be converted into strVar
#  str(intVar)         str(24)   --> '24'

# we have a floatVar which needs to be converted into strVar
#  str(floatVar)         str(24.334)   --> '24.334'

# converting bool into int and float


choice = True
print(int(choice))
print(float(choice))

choice = False
print(int(choice))
print(float(choice))

print(str(choice))

res = 1
print(bool(res))

name = "89.21"
print(float(name))
# Out:
# 55
# 1
# 1.0
# 0
# 0.0
# False
# True
# 89.21

# %%
# Taking an user input

# input()
# is a built-in function used to take input from the user
# input(prompt/message)

name = input("Enter Your Name : ")
print("Welcome User",name)

name = input("Nama : ")
print("Selamat Datang",name)
# Out:
# Enter Your Name : ash
# Welcome User ash
# Nama : ash
# Selamat Datang ash

# %%
print("Enter Your City")
City = input()
print("Your City is",City)
# Out:
# Enter Your City
# KK
# Your City is KK

# %%
# input() function will get the value in a form of string

val1 = input("Enter the First Value : ") #30
val2 = input("Enter the Second Value : ") #33
res = val1 + val2 #30 + 33
print(f"After Addition {val1} + {val2} Result Will Be {res}")
# Out:
# Enter the First Value : 30
# Enter the Second Value : 33
# After Addition 30 + 33 Result Will Be 3033

# %%
val1 = int(input("Enter the First Value : ")) #30
val2 = int(input("Enter the Second Value : ")) #33
res = val1 + val2 #30 + 33
print(f"After Addition {val1} + {val2} Result Will Be {res}")
# Out:
# Enter the First Value : 30
# Enter the Second Value : 33
# After Addition 30 + 33 Result Will Be 63

# %%
# BMI CALCULATOR

# ask user a name

# float ask user to insert weight in kg's

# float ask user to insert height in cm's

# convert height from cm to meter

# h_m = cm / 100

# calculate bmi = weight in kg / height in meters * height in meters

# string formatting Hi user John your BMI is ... :)


# BMI Exercise

print("BMI CALCULATOR")

name = input("Enter Your Name : ")
val1 = float(input("Enter Your Weight : "))
val2 = float(input("Enter Your Height : "))

h_meter = val2 / 100

BMI = val1 / (val2 * val2)

print(f"Hi user {name}, your BMI is {BMI}.")
# Out:
# BMI CALCULATOR
# Enter Your Name : John
# Enter Your Weight : 66.5
# Enter Your Height : 167.6
# Hi user John your BMI is 0.0023674107575144825

# %%
# Operators
# Operators are used to perform operations on Variables

# a.) ARITHMETIC OPERATORS
# ARE USED TO PERFORM MATHEMATICAL OPERATIONS ON VARIABLES
#  +  -   *    /   //  %  **

print(10+5)
print(10-5)
print(10*5)
print(10/5)  # IN PHYTON DIVIDION OPERATOR / USED TO RETURN VALUE IN FLOAT
print(10//5) # IN PHYTON FLOOR DIVIDION OPERATOR // USED TO RETURN VALUE IN INT
print(10%3)  # MODULUS USED TO GIVE REMAINDER
print(2**8)  # 2 RAISE TO THE POWER OF 8 **EXPONENT
print(72**72)
# Out:
# 15
# 5
# 50
# 2.0
# 2
# 1
# 256
# 53449019547361999534025300140057538544940601393106611570269540644280818850419033099696863861289188541180498511377339362341642322313216

# %%
# b.) ASSIGNMENT OPERATOR
# used to assign a value to a variable

a = 90 # a as 90 or a is 90
print(a)
# Out:
# 90

# %%
# c.) COMPARASION OPERATORS
# < > == != <= >=
# USED TO RETURN A BOOLEAN VALUE [TRUE/FALSE]

print(10<5)
print(10>5)
print(98==98)
print(100!=1000)
print(100!=100)

age = 18
print(age>=18) # age should be equal to 18 or greater than 18
# Out:
# False
# True
# True
# True
# False
# True

# %%
# d.) LOGICAL OPERATORS
#  works with multiple conditions
#  and  or  not
#  USED TO RETURN A BOOLEAN VALUE  [True / False]

# and
# and requires more than one condition
# and will return TRUE when both or all the conditions are TRUE

print(100==100 and 200==200 and 300==300)
#     true          true       true
print(100==100 and 200==2000)
#     true          false
# Out:
# True
# False

# %%
# or
# # or requires more than one condition
# or will return TRUE when both or all the conditions are TRUE
# or will also returns True if atleast any condition is TRUE
# or will return FALSE when both or all the conditions are FALSE


print(100==100 or 200==200 or 300==300)
#     true          true       true

print(100==100 or 200==2000)
#     true          false

print(100==1000 or 200==2000)
#     false         false
# Out:
# True
# True
# False

# %%
# not
# used to reverse the result

print(not(100==100 or 200==2000))
print(not(100==1000 or 200==2000))
# Out:
# False
# True

# %%
# e.) Membership Operations
# in   not in

# in
# used to return true
# if the specified value exists in a sequence

print("P" in "Phyton")
print("o" in "Phyton")
print("John" in ["John","smith","alex"])
print("x" in "Phyton")
print("p" in "Phyton")
# Out:
# True
# True
# True
# False
# False

# %%
# not in

print("x" not in "Python")

# hey interpreter I think that this x does not exist in Python
# yes you are Right

print("t" not in "Python")
# hey interpreter I think that this t does not exist in Python
# no you are wrong
# Out:
# True
# False
