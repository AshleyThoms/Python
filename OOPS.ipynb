# %%
# OOPS
# OOP stands for Object-Oriented Programming.
# Object-oriented programming (OOP) is a programming paradigm based on the
# concept of "objects"
# Procedural programming is about writing procedures or methods that perform operations
# on the data, while object-oriented programming is about creating objects
# that contain both data and methods.

# Object-oriented programming has several advantages over procedural programming:
# a.) OOP is faster and easier to execute
# b.) OOP provides a clear structure for the programs
# c.) OOP helps to keep the Java/Python code DRY "Don't Repeat Yourself", and makes the code easier
 # to maintain, modify and debug
# d.) OOP makes it possible to create full reusable applications with less code and
 # shorter development time

# Class

# A class is a blueprint that defines the variables and the methods common to all objects.
# a class is a collection of methods and variables


# Object

# An object is called an instance of a class.


# Self Keyword

# The self parameter is a reference to the current instance of the class, and is used to
# access variables that belongs to the class.
# The first parameter of each method in a class must be the self ,
# which refers to the calling object. However, you can give any name to the first
# parameter, not necessarily self.

# __init__ in Python

#  Constructors are used to initializing the object’s state. The task of constructors is
# to initialize(assign values) to the data members of the class when
# an object of the class is created.
# The __init__() function is called automatically every time the class is being used to create
# a new object.

# %%
# class in python
# a class is a collection of methods/ functions and variables
# in python a class can be defined by using a class keyword

class myClass:


  '''
  This is my first class in python
  I've just started learning OOPS
  '''


  a = 10     # member variable
  b = 20

  def func1():          # member function
    print('I am the method of a class')

  def func2():
    print('I am the another method of a class')

# %%
help(myClass)
# Out:
# Help on class myClass in module __main__:
#
# class myClass(builtins.object)
#  |  This is my first class in python
#  |  I've just started learning OOPS
#  |
#  |  Methods defined here:
#  |
#  |  func1()
#  |
#  |  func2()
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  a = 10
#  |
#  |  b = 20

# %%
class myClass:

  a = 10
  b = 20

  def func1():
    print('I am the method of a class')

  def func2():
    print('I am the another method of a class')

# we can not access class variables and functions directly
# we need to call these variables and function with the help of the class

print(myClass.a)    # . dot is a member access operator
myClass.func1()
# Out:
# 10
# I am the method of a class

# %%
class myClass:

  a = 10
  b = 20

  def func1():
    print('I am the method of a class')

  def func2():
    print('I am the another method of a class')

# In OOPS in order to access class variable and functions
# we need to define the Object of the class

# syntax of defining the object
# objName = className()

# object can access the class variable and functions
# in python a class can have and number of objects

obj1 = myClass()  # creating an object of a class
obj2 = myClass()  # creating an another object of a class

print(obj1.a)
print(obj1.b)

print(obj2.a)
print(obj2.b)
# Out:
# 10
# 20
# 10
# 20

# %%
class myClass:

  a = 10
  b = 20

  def func1():
    print('I am the method of a class')

  def func2():
    print('I am the another method of a class')


obj1 = myClass()
obj2 = myClass()

# A class share common properties among all objects
print(obj1.a , obj1.b)
print(obj2.a , obj2.b)

obj1.func1()
# Out:
# 10 20
# 10 20
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1866/1074552216.py in <cell line: 0>()
#      18 print(obj2.a , obj2.b)
#      19
# ---> 20 obj1.func1()
#
# TypeError: myClass.func1() takes 0 positional arguments but 1 was given

# %%
# This error says
# myClass.func1() takes 0 positional arguments
# this function is a function without parameter

# but 1 was given
# but when you are calling or using this function
# you are providing one argument

# %%
# Self Keyword

# ==== Important Rule ======
# whenever you are defining any function inside the class
# the first parameter of that function need to be self


class myClass:      # 3. giving your class a clear idea that who wants to use this function now

  a = 10
  b = 20

  def func1(self):                         # 2. self value will be replace obj1 func1(obj1) func1(obj2)
    print('I am the method of a class')

  def func2(self):
    print('I am the another method of a class')


obj1 = myClass()
obj2 = myClass()

obj1.func1()     # 1. here i am calling the func1() with the help of obj1
obj2.func1()

# %%
class myClass:      # 3. giving your class a clear idea that who wants to use this function now

  a = 10
  b = 20

  def func1(self):                         # 2. self value will be replace obj1 func1(obj1) func1(obj2)
    print('I am the method of a class')

  def func2(self,x,y):
    print('I am the another method of a class')


obj1 = myClass()
obj2 = myClass()

obj1.func1()
obj2.func1()

obj1.func2(10,20)    # 1. here i am calling the func1() with the help of obj1

# %%
# Design an application for me using procedure programming
# use registeration system

# Task 1
# Take 3 information from 3 user
# user 1     user 2      user3
# name       name        name
# email      email       email
# mobno      mobno       mobno

# Task 2
# Print all this infomation

# Task 3
# Print only the second user information

# Task 4
# Print the email and mobno of 3rd user


users = []

for i in range(1,4):
  print('Enter user details', i)

  name = input('Enter your name: ')
  email = input('Enter your email: ')
  mobno = input('Enter your mobno: ')

  user =[name,email,mobno]
  users.append(user)

print(users)


print('All user information: ')
for user in users:
  print('name', users[0], 'email', users[1], 'mobno', users[2])

print()

print('Second user information: ')
print('name', users[1][0])
print('email', users[1][1])
print('mobno', users[1][2])

print()

print('Third user email and mobno: ')
print('email', users[2][1])
print('mobno', users[2][2])

print()

# %%
# Python OOP provides us a special function named as __init__()
#  __init__() can help you to provide diff diff data value to a class variables
#  this special function will call itself the moment when you create the
#  object of a class

# %%
class userInfo:

    def __init__(self,n,e,mn):    # us3  , n = Smith  ,   e = sm@gmail.com  , mn = 60690231
        self.name = n
        self.email = e
        self.mobno = mn

    def printDetails(self):                            # printDetails(us1)                       printDetails(us2)
        print(self.name,self.email,self.mobno)         #   us1.name us1.email us1.mobno           us2.name us2.email us2.mobno

us1 = userInfo("John","j@gmail.com",60987654)  # __init__ calls itself and this information ("John","j@gmail.com",60987654) will be passed to it automatically
us2 = userInfo("Alex","al@gmail.com",60453213) # __init__ calls itself and this information ("Alex","al@gmail.com",60453213) will be passed to it automatically
us3 = userInfo("Smith","sm@gmail.com",60690231) # __init__ calls itself and this information ("Smith","sm@gmail.com",60690231) will be passed to it automatically

print("====Printing All Information====")
us1.printDetails()
us2.printDetails()
us3.printDetails()

print("\n====Printing Second User Information====")
us2.printDetails()

print("\n====Printing Email and MobNo Of 3rd User====")
print(us3.email)
print(us3.mobno)
# Out:
# ====Printing All Information====
# John j@gmail.com 60987654
# Alex al@gmail.com 60453213
# Smith sm@gmail.com 60690231
#
# ====Printing Second User Information====
# Alex al@gmail.com 60453213
#
# ====Printing Email and MobNo Of 3rd User====
# sm@gmail.com
# 60690231

# %%
class userInfo:

    def __init__(self,n,e,mn):
        self.name = n
        self.email = e
        self.mobno = mn

    def printDetails(self):
        print(self.name,self.email,self.mobno)

us1 = userInfo("John","j@gmail.com",60987654)
us2 = userInfo("Alex","al@gmail.com",60453213)
us3 = userInfo("Smith","sm@gmail.com",60690231)

print("====Printing All Information====")
us1.printDetails()
us2.printDetails()
us3.printDetails()

print("\n====Printing Second User Information====")
us2.printDetails()

print("\n====Printing Email and MobNo Of 3rd User====")
print(us3.email)
print(us3.mobno)
# Out:
# ====Printing All Information====
# John j@gmail.com 60987654
# Alex al@gmail.com 60453213
# Smith sm@gmail.com 60690231
#
# ====Printing Second User Information====
# Alex al@gmail.com 60453213
#
# ====Printing Email and MobNo Of 3rd User====
# sm@gmail.com
# 60690231
